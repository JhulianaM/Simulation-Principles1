# %% [markdown]
# <a href="https://colab.research.google.com/github/JhulianaM/Simulation-Principles1/blob/master/Ex_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt


N=10000
lambda1=1/28
x=np.random.uniform(0,1,N)

Xexp=-np.log(x)/lambda1

print(Xexp)
X=np.arange(0, 10, 0.1)
fx=lambda1*np.exp(-lambda1*X)
plt.plot(X,fx)
plt.hist(Xexp,bins=100,density=True)
plt.show()
# Out:
# [52.91427033  6.41419349 60.09241383 ... 22.36988773 42.58195635
#  54.60722335]

# %%
# Intervalo de x para o gráfico
x = np.linspace(0, 60, 1000)

# Calcula a PDF para o intervalo de x
pdf = expon.pdf(x, scale=28)

# Traça a PDF
plt.plot(x, pdf, 'b-', lw=2)
plt.title('Função Densidade de Probabilidade da Distribuição Exponencial')
plt.xlabel('Dias')
plt.ylabel('Densidade de Probabilidade')
plt.grid(True)
plt.show()
