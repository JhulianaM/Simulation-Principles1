# %% [markdown]
# <a href="https://colab.research.google.com/github/JhulianaM/Simulation-Principles1/blob/master/Ex8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

n=10000
xfunction=np.array([])

for i in range(n):
    x1=np.random.uniform(-1,1)
    x2=np.random.uniform(0,1)

    while (x2 >=(1/9)*pow(x1,2)):
        x1=np.random.uniform(-1,1)
        x2=np.random.uniform(0,1)
    xfunction = np.append(xfunction, x1)

print(xfunction)
X=np.arange(-1, 1, 0.1)
fx=1.5*pow(X,2)
plt.plot(X,fx)
plt.hist(xfunction,bins=100,density=True)
plt.show()
# Out:
# [ 0.59976043 -0.93541042  0.77638311 ...  0.91762835 -0.93587568
#   0.95086775]
